# %%
import xarray as xr
import getpass

# %%
dirin='/scratch/'+getpass.getuser()+'/clim670/ccpp-scm-7.0/'
filin='output_bomex_SCM_GFS_v16/output.nc'

# %%
ds=xr.open_dataset(dirin+filin)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:               (time_inst_dim: 145, time_diag_dim: 24,
#                            time_swrad_dim: 73, time_lwrad_dim: 73,
#                            time_rad_dim: 73, vert_dim_layer: 127,
#                            hor_dim_layer: 1, vert_dim_interface: 128,
#                            vert_dim_rad: 127)
# Dimensions without coordinates: time_inst_dim, time_diag_dim, time_swrad_dim,
#                                 time_lwrad_dim, time_rad_dim, vert_dim_layer,
#                                 hor_dim_layer, vert_dim_interface, vert_dim_rad
# Data variables: (12/135)
#     time_inst             (time_inst_dim) float32 ...
#     time_diag             (time_diag_dim) float32 ...
#     time_swrad            (time_swrad_dim) float32 ...
#     time_lwrad            (time_lwrad_dim) float32 ...
#     time_rad              (time_rad_dim) float32 ...
#     pres                  (time_inst_dim, vert_dim_layer, hor_dim_layer) float32 ...
# ...
